# %%
import requests,json
import pandas as pd

url = "https://zillow56.p.rapidapi.com/search"

querystring = {"location":"houston, tx"}

headers = {
	"X-RapidAPI-Key": "a67df7d0demshdxxxxxxxxxxxxxxxxxafdejsn8014175aacf8",
	"X-RapidAPI-Host": "zillow56.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
response=json.loads(response.content)

print(response)
# Convert the dictionary to a Pandas data frame

df = pd.DataFrame.from_dict(response_dict)

# Extract the information from the 'results' column
result_df = json_normalize(df['results'])

# Write the result data frame to a CSV file
result_df.to_csv('houston_real_estate_results.csv', index=False)
# Out:
# {'abbreviatedAddress': 'N 18th Street At Seattle St', 'address': {'city': 'Nederland', 'community': None, 'neighborhood': None, 'state': 'TX', 'streetAddress': 'N 18th Street At Seattle St', 'subdivision': None, 'zipcode': '77627'}, 'apartmentsForRentInZipcodeSearchUrl': {'path': '/nederland-tx-77627/apartments/'}, 'attributionInfo': {'agentEmail': None, 'agentLicenseNumber': None, 'agentName': None, 'agentPhoneNumber': '409-338-9550', 'attributionTitle': None, 'brokerName': 'RE/MAX One', 'brokerPhoneNumber': '409-860-3200', 'buyerAgentMemberStateLicense': None, 'buyerAgentName': None, 'buyerBrokerageName': None, 'coAgentLicenseNumber': None, 'coAgentName': None, 'coAgentNumber': None, 'infoList1': [{'infoField1': 'listOffice', 'infoField2': 'RE/MAX One'}], 'infoList2': [{'infoField1': None, 'infoField2': 'listAgent', 'infoField3': None}], 'infoString1': '231738', 'infoString10': None, 'infoString11': None, 'infoString12': None, 'infoString13': None, 'infoString14': None, 'infoString
# ...

# %%
data=pd.read_csv('houston_real_estate_results.csv')

# %%
data.head()
# Out:
#    bathrooms  bedrooms     city country currency  daysOnZillow homeStatus  \
# 0        3.0       4.0  Houston     USA      USD             0   FOR_SALE
# 1        2.0       3.0  Houston     USA      USD             0   FOR_SALE
# 2        3.0       4.0   Humble     USA      USD             0   FOR_SALE
# 3        2.0       3.0   Humble     USA      USD             0   FOR_SALE
# 4        0.0       NaN  Houston     USA      USD             0   FOR_SALE
#
#   homeStatusForHDP       homeType  \
# 0         FOR_SALE  SINGLE_FAMILY
# 1         FOR_SALE  SINGLE_FAMILY
# 2         FOR_SALE  SINGLE_FAMILY
# 3         FOR_SALE  SINGLE_FAMILY
# 4         FOR_SALE            LOT
#
#                                               imgSrc  ...  \
# 0  https://maps.googleapis.com/maps/api/staticmap...  ...
# 1  https://photos.zillowstatic.com/fp/8720122bed0...  ...
# 2  https://photos.zillowstatic.com/fp/ca017566196...  ...
# 3  https://photos.zillowstatic.com/fp/13ffab55f0d...  ...
# ...
